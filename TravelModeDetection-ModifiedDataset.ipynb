# %%
from TMDataset import TMDataset
from TMDetection import TMDetection
dataset = TMDataset()
dataset.create_balanced_dataset(False,True,True,True,True,True,True)
detection = TMDetection(dataset)
# Out:
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# START CREATE BALANCED DATASET....
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2825: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# END CREATE BALANCED DATASET....
# HAVE_DT True
# ['Bus' 'Bus' 'Bus' ..., 'Walking' 'Walking' 'Walking']

# %%
detection.decision_tree(1)
detection.decision_tree(2)
detection.decision_tree(3)
# Out:
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.720207253886
# REPORT :              precision    recall  f1-score   support
#
#           0       0.65      0.63      0.64       671
#           1       0.67      0.65      0.66       654
#           2       0.83      0.80      0.81       654
#           3       0.62      0.65      0.63       646
#           4       0.84      0.87      0.85       656
#
# avg / total       0.72      0.72      0.72      3281
#
# CONFUSION MATRIX : [[426  92  21  87  45]
#  [ 85 424  17 113  15]
#  [ 36  19 522  40  37]
#  [ 79  87  46 418  16]
#  [ 34  13  22  14 573]]
# SPLIT TIME: 0.326
# FIT TIME: 0.058
# SCORE TIME: 0.009
# SPLIT TIME: 0.329
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.651535301117
# MEAN PRECISION: 0.647583090692
# MEAN RECALL: 0.651680545917
# MEAN F-MEASURE: 0.643170749467
# MEAN FIT TIME: 0.124341511726
# MEAN SCORE TIME: 0.00341231822968
# END TREE
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.765315452606
# REPORT :              precision    recall  f1-score   support
#
#           0       0.71      0.74      0.72       671
#           1       0.68      0.64      0.66       654
#           2       0.83      0.81      0.82       654
#           3       0.76      0.75      0.75       646
#           4       0.84      0.89      0.86       656
#
# avg / total       0.76      0.77      0.76      3281
#
# CONFUSION MATRIX : [[495  78  20  34  44]
#  [107 420  34  81  12]
#  [ 23  26 532  32  41]
#  [ 40  70  39 483  14]
#  [ 35  21  14   5 581]]
# SPLIT TIME: 0.327
# FIT TIME: 0.164
# SCORE TIME: 0.009
# SPLIT TIME: 0.333
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.650199730983
# MEAN PRECISION: 0.64705563067
# MEAN RECALL: 0.65032153597
# MEAN F-MEASURE: 0.63871069067
# MEAN FIT TIME: 0.34666686058
# MEAN SCORE TIME: 0.00332016944885
# END TREE
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.816824138982
# REPORT :              precision    recall  f1-score   support
#
#           0       0.77      0.79      0.78       671
#           1       0.80      0.79      0.80       654
#           2       0.83      0.84      0.83       654
#           3       0.81      0.79      0.80       646
#           4       0.87      0.87      0.87       656
#
# avg / total       0.82      0.82      0.82      3281
#
# CONFUSION MATRIX : [[531  55  26  31  28]
#  [ 57 516  14  45  22]
#  [ 29  10 547  38  30]
#  [ 39  44  45 513   5]
#  [ 34  19  26   4 573]]
# SPLIT TIME: 0.336
# FIT TIME: 0.16
# SCORE TIME: 0.01
# SPLIT TIME: 0.318
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.713435115001
# MEAN PRECISION: 0.710190026378
# MEAN RECALL: 0.713527642841
# MEAN F-MEASURE: 0.698130230341
# MEAN FIT TIME: 0.356594252586
# MEAN SCORE TIME: 0.00332462787628
# END TREE

# %%
detection.random_forest(1)
detection.random_forest(2)
detection.random_forest(3)
# Out:
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.823224626638
# REPORT :              precision    recall  f1-score   support
#
#           0       0.75      0.79      0.77       671
#           1       0.78      0.73      0.75       654
#           2       0.89      0.89      0.89       654
#           3       0.78      0.77      0.78       646
#           4       0.90      0.93      0.92       656
#
# avg / total       0.82      0.82      0.82      3281
#
# CONFUSION MATRIX : [[530  49  20  41  31]
#  [ 89 475  11  69  10]
#  [ 19  11 585  24  15]
#  [ 45  63  28 500  10]
#  [ 19  10  11   5 611]]
# SPLIT TIME: 0.314
# FIT TIME: 0.936
# SCORE TIME: 0.067
# SPLIT TIME: 0.324
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.727736303812
# MEAN PRECISION: 0.718351785287
# MEAN RECALL: 0.727878787879
# MEAN F-MEASURE: 0.715855255371
# MEAN FIT TIME: 1.75025441647
# MEAN SCORE TIME: 0.0835505247116
# END RANDOM FOREST
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.886315147821
# REPORT :              precision    recall  f1-score   support
#
#           0       0.81      0.89      0.85       671
#           1       0.88      0.83      0.86       654
#           2       0.94      0.91      0.92       654
#           3       0.89      0.87      0.88       646
#           4       0.91      0.93      0.92       656
#
# avg / total       0.89      0.89      0.89      3281
#
# CONFUSION MATRIX : [[599  20   6  15  31]
#  [ 63 543   8  31   9]
#  [ 21  10 595  20   8]
#  [ 25  37  16 559   9]
#  [ 28   6   9   1 612]]
# SPLIT TIME: 0.314
# FIT TIME: 1.326
# SCORE TIME: 0.071
# SPLIT TIME: 0.301
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.745613232368
# MEAN PRECISION: 0.743592083038
# MEAN RECALL: 0.745697432339
# MEAN F-MEASURE: 0.733933658701
# MEAN FIT TIME: 2.60299406052
# MEAN SCORE TIME: 0.0817167282104
# END RANDOM FOREST
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.918012800975
# REPORT :              precision    recall  f1-score   support
#
#           0       0.85      0.91      0.88       671
#           1       0.95      0.86      0.91       654
#           2       0.96      0.93      0.95       654
#           3       0.93      0.93      0.93       646
#           4       0.91      0.96      0.94       656
#
# avg / total       0.92      0.92      0.92      3281
#
# CONFUSION MATRIX : [[609  14   2  19  27]
#  [ 55 565   8  13  13]
#  [ 16   4 611  11  12]
#  [ 22   6  13 598   7]
#  [ 17   5   5   0 629]]
# SPLIT TIME: 0.322
# FIT TIME: 1.456
# SCORE TIME: 0.069
# SPLIT TIME: 0.324
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.799905712412
# MEAN PRECISION: 0.804597411077
# MEAN RECALL: 0.799975711312
# MEAN F-MEASURE: 0.788384137631
# MEAN FIT TIME: 2.71897127628
# MEAN SCORE TIME: 0.080188703537
# END RANDOM FOREST

# %%
detection.support_vector_machine(1)
detection.support_vector_machine(2)
detection.support_vector_machine(3)
# Out:
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.647973178909
# REPORT :              precision    recall  f1-score   support
#
#           0       0.67      0.59      0.63       671
#           1       0.68      0.54      0.60       654
#           2       0.80      0.59      0.68       654
#           3       0.69      0.56      0.62       646
#           4       0.54      0.96      0.69       656
#
# avg / total       0.68      0.65      0.64      3281
#
# CONFUSION MATRIX : [[395  72  23  51 130]
#  [ 92 351  11  74 126]
#  [ 26  11 387  37 193]
#  [ 68  77  54 361  86]
#  [  8   2  10   4 632]]
# SPLIT TIME: 0.364
# SCALE TIME: 0.002
# FIT TIME: 1.496
# SCORE TIME: 0.462
# SPLIT TIME: 0.327
# SCALE TIME: 0.002
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.591489996345
# MEAN PRECISION: 0.596803117174
# MEAN RECALL: 0.591614619477
# MEAN F-MEASURE: 0.572682753947
# MEAN FIT TIME: 3.99456520081
# MEAN SCORE TIME: 0.626385712624
# END SUPPORT VECTOR MACHINE.....
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.775678146906
# REPORT :              precision    recall  f1-score   support
#
#           0       0.79      0.76      0.77       671
#           1       0.82      0.69      0.75       654
#           2       0.86      0.74      0.80       654
#           3       0.83      0.74      0.78       646
#           4       0.66      0.95      0.78       656
#
# avg / total       0.79      0.78      0.78      3281
#
# CONFUSION MATRIX : [[508  45  23  21  74]
#  [ 77 452  14  37  74]
#  [ 14   4 487  40 109]
#  [ 31  41  31 477  66]
#  [ 16   8  11   0 621]]
# SPLIT TIME: 0.331
# SCALE TIME: 0.004
# FIT TIME: 1.804
# SCORE TIME: 0.778
# SPLIT TIME: 0.328
# SCALE TIME: 0.005
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.662395254219
# MEAN PRECISION: 0.657652132825
# MEAN RECALL: 0.66248901226
# MEAN F-MEASURE: 0.644336840085
# MEAN FIT TIME: 4.81155161858
# MEAN SCORE TIME: 1.01493980885
# END SUPPORT VECTOR MACHINE.....
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.801889667784
# REPORT :              precision    recall  f1-score   support
#
#           0       0.85      0.79      0.82       671
#           1       0.90      0.74      0.81       654
#           2       0.90      0.75      0.81       654
#           3       0.86      0.76      0.81       646
#           4       0.63      0.96      0.77       656
#
# avg / total       0.83      0.80      0.80      3281
#
# CONFUSION MATRIX : [[533  13  19  23  83]
#  [ 47 482  12  20  93]
#  [ 12   5 489  35 113]
#  [ 26  29  22 494  75]
#  [  9   9   4   1 633]]
# SPLIT TIME: 0.327
# SCALE TIME: 0.003
# FIT TIME: 1.919
# SCORE TIME: 0.813
# SPLIT TIME: 0.312
# SCALE TIME: 0.006
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.711790146733
# MEAN PRECISION: 0.723666279636
# MEAN RECALL: 0.711844783715
# MEAN F-MEASURE: 0.695763001079
# MEAN FIT TIME: 5.26399476528
# MEAN SCORE TIME: 1.07627818584
# END SUPPORT VECTOR MACHINE.....

# %%
detection.neural_network(1)
detection.neural_network(2)
detection.neural_network(3)
# Out:
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ACCURACY : 0.766534593112
# REPORT :              precision    recall  f1-score   support
#
#           0       0.70      0.74      0.72       671
#           1       0.69      0.65      0.67       654
#           2       0.83      0.85      0.84       654
#           3       0.72      0.70      0.71       646
#           4       0.89      0.89      0.89       656
#
# avg / total       0.77      0.77      0.77      3281
#
# CONFUSION MATRIX : [[498  77  25  45  26]
#  [111 423  25  82  13]
#  [ 19  18 557  34  26]
#  [ 63  75  48 451   9]
#  [ 21  17  19  13 586]]
# SPLIT TIME: 0.356
# SCALE TIME: 0.001
# FIT TIME: 50.71
# SCORE TIME: 0.053
# SPLIT TIME: 0.33
# SCALE TIME: 0.002
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.676695507886
# MEAN PRECISION: 0.668227778164
# MEAN RECALL: 0.676830904464
# MEAN F-MEASURE: 0.666146946496
# MEAN FIT TIME: 86.2584403515
# MEAN SCORE TIME: 0.0244976043701
# END NEURAL NETWORK
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.811338006705
# REPORT :              precision    recall  f1-score   support
#
#           0       0.76      0.77      0.77       671
#           1       0.76      0.74      0.75       654
#           2       0.84      0.85      0.84       654
#           3       0.79      0.78      0.79       646
#           4       0.90      0.92      0.91       656
#
# avg / total       0.81      0.81      0.81      3281
#
# CONFUSION MATRIX : [[518  60  31  37  25]
#  [ 87 483  21  50  13]
#  [ 16  20 556  39  23]
#  [ 33  59  43 504   7]
#  [ 24  15  11   5 601]]
# SPLIT TIME: 0.315
# SCALE TIME: 0.003
# FIT TIME: 55.158
# SCORE TIME: 0.045
# SPLIT TIME: 0.323
# SCALE TIME: 0.004
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.685564223599
# MEAN PRECISION: 0.673054287168
# MEAN RECALL: 0.685653481379
# MEAN F-MEASURE: 0.671157648171
# MEAN FIT TIME: 98.4615160704
# MEAN SCORE TIME: 0.0256721973419
# END NEURAL NETWORK
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.861322767449
# REPORT :              precision    recall  f1-score   support
#
#           0       0.82      0.84      0.83       671
#           1       0.83      0.82      0.82       654
#           2       0.87      0.88      0.88       654
#           3       0.87      0.83      0.85       646
#           4       0.91      0.93      0.92       656
#
# avg / total       0.86      0.86      0.86      3281
#
# CONFUSION MATRIX : [[564  32  26  29  20]
#  [ 61 536  21  25  11]
#  [ 19  14 577  24  20]
#  [ 28  47  26 539   6]
#  [ 15  18  11   2 610]]
# SPLIT TIME: 0.319
# SCALE TIME: 0.003
# FIT TIME: 39.309
# SCORE TIME: 0.028
# SPLIT TIME: 0.306
# SCALE TIME: 0.004
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.741975553988
# MEAN PRECISION: 0.727480694948
# MEAN RECALL: 0.742034466805
# MEAN F-MEASURE: 0.724139474921
# MEAN FIT TIME: 71.0396932125
# MEAN SCORE TIME: 0.0183879852295
# END NEURAL NETWORK
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
detection.auto_machine_learning(1, search_time=300)
detection.auto_machine_learning(2, search_time=300)
detection.auto_machine_learning(3, search_time=300)
# Out:
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.437652)
# StatusType.SUCCESS 0.180055401662 1.1048219203948975 {'num_run': 2, 'duration': 1.056934118270874}
# StatusType.SUCCESS 0.168051708218 9.671364545822144 {'num_run': 3, 'duration': 9.617214918136597}
# StatusType.SUCCESS 0.337950138504 0.6446182727813721 {'num_run': 4, 'duration': 0.6180820465087891}
# StatusType.SUCCESS 0.149584487535 44.339131355285645 {'num_run': 5, 'duration': 44.21372199058533}
# StatusType.SUCCESS 0.327793167128 1.607757329940796 {'num_run': 6, 'duration': 1.5741369724273682}
# StatusType.SUCCESS 0.299168975069 0.8656163215637207 {'num_run': 7, 'duration': 0.8390007019042969}
# StatusType.SUCCESS 0.165281625115 9.701151847839355 {'num_run': 8, 'duration': 9.650547742843628}
# StatusType.SUCCESS 0.331486611265 4.364703416824341 {'num_run': 9, 'duration': 4.310621023178101}
# StatusType.SUCCESS 0.576177285319 0.8654477596282959 {'num_run': 10, 'duration': 0.8305234909057617}
# StatusType.SUCCESS 0.397045244691 1.3540494441986084 {'num_run': 11, 'duration': 1.3272886276245117}
# StatusType.SUCCESS 0.232686980609 4.533621311187744 {'num_run': 12, 'duration': 4.4976396560668945}
# StatusType.SUCCESS 0.3702677747 2.4317514896392822 {'num_run': 13, 'duration': 2.4031472206115723}
# StatusType.TIMEOUT 1.0 206.04923963546753 {'error': 'Timeout'}
# ACCURACY : 0.833282535812
# REPORT :              precision    recall  f1-score   support
#
#           0       0.78      0.82      0.80       671
#           1       0.77      0.72      0.74       654
#           2       0.90      0.90      0.90       654
#           3       0.81      0.78      0.80       646
#           4       0.90      0.94      0.92       656
#
# avg / total       0.83      0.83      0.83      3281
#
# CONFUSION MATRIX : [[551  52  16  22  30]
#  [ 85 470  12  69  18]
#  [ 19  11 591  24   9]
#  [ 37  68  25 507   9]
#  [ 17   9  10   5 615]]
# SPLIT TIME: 0.3
# FIT TIME: 296.958
# SCORE TIME: 0.671
# FINAL ENSEMBLE: [(0.920000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.040000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:random_forest:max_features': 1.0, 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'classifier:random_forest:criterion': 'gini', 'one_hot_encoding:minimum_fraction': 0.01, 'balancing:strategy': 'none', 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:bootstrap': 'True', 'classifier:__choice__': 'random_forest', 'rescaling:__choice__': 'standardize', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean', 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:adaboost:max_depth': 5, 'classifier:__choice__': 'adaboost', 'classifier:adaboost:n_estimators': 497, 'classifier:adaboost:learning_rate': 0.5963067322132379, 'rescaling:__choice__': 'minmax', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'False', 'imputation:strategy': 'mean', 'classifier:adaboost:algorithm': 'SAMME', 'balancing:strategy': 'none'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.33
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.889351353699
# MEAN PRECISION: 0.889760899722
# MEAN RECALL: 0.889383529956
# MEAN F-MEASURE: 0.889093121484
# MEAN FIT TIME: 142.7652
# MEAN SCORE TIME: 0.2055
# END AUTO MACHINE LEARNING
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.489599)
# StatusType.SUCCESS 0.119113573407 1.3411455154418945 {'num_run': 2, 'duration': 1.2983081340789795}
# StatusType.SUCCESS 0.0849492151431 25.366392850875854 {'num_run': 3, 'duration': 25.303032636642456}
# StatusType.SUCCESS 0.0710987996307 54.07427740097046 {'num_run': 4, 'duration': 53.95882058143616}
# StatusType.SUCCESS 0.244690674054 0.7495055198669434 {'num_run': 5, 'duration': 0.716468095779419}
# StatusType.SUCCESS 0.218836565097 3.650604009628296 {'num_run': 6, 'duration': 3.602491617202759}
# StatusType.SUCCESS 0.320406278855 2.913038730621338 {'num_run': 7, 'duration': 2.8824119567871094}
# StatusType.SUCCESS 0.576177285319 1.0085792541503906 {'num_run': 8, 'duration': 0.9653725624084473}
# StatusType.TIMEOUT 1.0 198.1122851371765 {'error': 'Timeout'}
# ACCURACY : 0.91587930509
# REPORT :              precision    recall  f1-score   support
#
#           0       0.87      0.92      0.90       671
#           1       0.91      0.85      0.88       654
#           2       0.94      0.93      0.93       654
#           3       0.92      0.92      0.92       646
#           4       0.93      0.96      0.95       656
#
# avg / total       0.92      0.92      0.92      3281
#
# CONFUSION MATRIX : [[619  15  12   4  21]
#  [ 52 558   9  25  10]
#  [ 14   7 605  19   9]
#  [ 11  30   8 592   5]
#  [ 12   4   7   2 631]]
# SPLIT TIME: 0.361
# FIT TIME: 295.276
# SCORE TIME: 0.717
# FINAL ENSEMBLE: [(0.980000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.020000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.328
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.951828994374
# MEAN PRECISION: 0.952362928277
# MEAN RECALL: 0.951835530881
# MEAN F-MEASURE: 0.951821367649
# MEAN FIT TIME: 217.956
# MEAN SCORE TIME: 0.2297
# END AUTO MACHINE LEARNING
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.490483)
# StatusType.SUCCESS 0.084025854109 1.3432331085205078 {'num_run': 2, 'duration': 1.2882609367370605}
# StatusType.SUCCESS 0.0572483841182 54.86334753036499 {'num_run': 3, 'duration': 54.68062353134155}
# StatusType.SUCCESS 0.0590951061865 26.234232425689697 {'num_run': 4, 'duration': 26.168309211730957}
# StatusType.SUCCESS 0.176361957525 0.7122128009796143 {'num_run': 5, 'duration': 0.6753160953521729}
# StatusType.SUCCESS 0.573407202216 0.8853762149810791 {'num_run': 6, 'duration': 0.8368062973022461}
# StatusType.SUCCESS 0.154201292705 3.263557195663452 {'num_run': 7, 'duration': 3.213667154312134}
# StatusType.SUCCESS 0.242843951985 2.867532968521118 {'num_run': 8, 'duration': 2.8350887298583984}
# StatusType.TIMEOUT 1.0 197.11222124099731 {'error': 'Timeout'}
# ACCURACY : 0.940262115209
# REPORT :              precision    recall  f1-score   support
#
#           0       0.89      0.94      0.91       671
#           1       0.96      0.90      0.93       654
#           2       0.95      0.95      0.95       654
#           3       0.96      0.95      0.95       646
#           4       0.94      0.96      0.95       656
#
# avg / total       0.94      0.94      0.94      3281
#
# CONFUSION MATRIX : [[629   9   9   6  18]
#  [ 40 589   8   8   9]
#  [ 11   2 621  11   9]
#  [ 12   7  11 613   3]
#  [ 13   4   6   0 633]]
# SPLIT TIME: 0.357
# FIT TIME: 295.64
# SCORE TIME: 0.352
# FINAL ENSEMBLE: [(0.980000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.020000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.32
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.969668860483
# MEAN PRECISION: 0.970031931937
# MEAN RECALL: 0.969676150821
# MEAN F-MEASURE: 0.969671939526
# MEAN FIT TIME: 144.9813
# MEAN SCORE TIME: 0.0977
# END AUTO MACHINE LEARNING

# %%
detection.decision_tree(1, apply_pca=True, number_of_components=3)
detection.decision_tree(2, apply_pca=True, number_of_components=8)
detection.decision_tree(3, apply_pca=True, number_of_components=9)
# Out:
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.328863151478
# REPORT :              precision    recall  f1-score   support
#
#           0       0.28      0.33      0.30       671
#           1       0.26      0.26      0.26       654
#           2       0.36      0.33      0.35       654
#           3       0.29      0.17      0.22       646
#           4       0.42      0.55      0.48       656
#
# avg / total       0.32      0.33      0.32      3281
#
# CONFUSION MATRIX : [[221 144  91  87 128]
#  [199 172 113  66 104]
#  [115  67 215  68 189]
#  [172 160 132 113  69]
#  [ 91 113  40  54 358]]
# SPLIT TIME: 0.526
# FIT TIME: 0.02
# SCORE TIME: 0.012
# SPLIT TIME: 0.363
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.47183622599
# MEAN PRECISION: 0.472262909837
# MEAN RECALL: 0.471970853574
# MEAN F-MEASURE: 0.466777306144
# MEAN FIT TIME: 0.0294832706451
# MEAN SCORE TIME: 0.00417437553406
# END TREE
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.382200548613
# REPORT :              precision    recall  f1-score   support
#
#           0       0.33      0.45      0.38       671
#           1       0.34      0.45      0.39       654
#           2       0.43      0.36      0.39       654
#           3       0.39      0.25      0.30       646
#           4       0.50      0.39      0.44       656
#
# avg / total       0.40      0.38      0.38      3281
#
# CONFUSION MATRIX : [[303 143  88  66  71]
#  [152 297  91  60  54]
#  [125 103 238  81 107]
#  [188 163 107 160  28]
#  [147 175  33  45 256]]
# SPLIT TIME: 0.42
# FIT TIME: 0.047
# SCORE TIME: 0.014
# SPLIT TIME: 0.471
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.57538366676
# MEAN PRECISION: 0.57349910652
# MEAN RECALL: 0.575499653019
# MEAN F-MEASURE: 0.567886263921
# MEAN FIT TIME: 0.0648154258728
# MEAN SCORE TIME: 0.00356895923615
# END TREE
# DECISION TREE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.328558366352
# REPORT :              precision    recall  f1-score   support
#
#           0       0.27      0.39      0.32       671
#           1       0.19      0.29      0.23       654
#           2       0.60      0.33      0.42       654
#           3       0.23      0.14      0.17       646
#           4       0.56      0.49      0.52       656
#
# avg / total       0.37      0.33      0.33      3281
#
# CONFUSION MATRIX : [[264 237  43  56  71]
#  [219 189  41 147  58]
#  [170 166 215  38  65]
#  [246 219  35  88  58]
#  [ 67 194  27  46 322]]
# SPLIT TIME: 0.397
# FIT TIME: 0.034
# SCORE TIME: 0.009
# SPLIT TIME: 0.354
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.626102332578
# MEAN PRECISION: 0.622575793455
# MEAN RECALL: 0.626197085357
# MEAN F-MEASURE: 0.615283169228
# MEAN FIT TIME: 0.0799921512604
# MEAN SCORE TIME: 0.00374145507812
# END TREE

# %%
detection.random_forest(1, apply_pca=True, number_of_components=3)
detection.random_forest(2, apply_pca=True, number_of_components=8)
detection.random_forest(3, apply_pca=True, number_of_components=9)
# Out:
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.399268515696
# REPORT :              precision    recall  f1-score   support
#
#           0       0.32      0.37      0.34       671
#           1       0.30      0.32      0.31       654
#           2       0.46      0.55      0.50       654
#           3       0.35      0.20      0.26       646
#           4       0.56      0.56      0.56       656
#
# avg / total       0.40      0.40      0.39      3281
#
# CONFUSION MATRIX : [[245 158 104  67  97]
#  [155 207 128  73  91]
#  [112  71 361  46  64]
#  [180 155 144 132  35]
#  [ 84  99  47  61 365]]
# SPLIT TIME: 0.365
# FIT TIME: 0.487
# SCORE TIME: 0.07
# SPLIT TIME: 0.354
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.525766634683
# MEAN PRECISION: 0.5291867171
# MEAN RECALL: 0.525913717326
# MEAN F-MEASURE: 0.516889010308
# MEAN FIT TIME: 0.823092746735
# MEAN SCORE TIME: 0.102267241478
# END RANDOM FOREST
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.479731789089
# REPORT :              precision    recall  f1-score   support
#
#           0       0.41      0.58      0.48       671
#           1       0.40      0.49      0.44       654
#           2       0.66      0.42      0.52       654
#           3       0.55      0.29      0.38       646
#           4       0.52      0.61      0.56       656
#
# avg / total       0.51      0.48      0.48      3281
#
# CONFUSION MATRIX : [[392 105  45  39  90]
#  [152 320  38  39 105]
#  [119  64 277  65 129]
#  [172 194  47 185  48]
#  [112 123  12   9 400]]
# SPLIT TIME: 0.38
# FIT TIME: 0.753
# SCORE TIME: 0.079
# SPLIT TIME: 0.362
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.670786658848
# MEAN PRECISION: 0.671587499438
# MEAN RECALL: 0.670894055054
# MEAN F-MEASURE: 0.662829301314
# MEAN FIT TIME: 1.27646915913
# MEAN SCORE TIME: 0.0962252378464
# END RANDOM FOREST
# RANDOM FOREST.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.329167936605
# REPORT :              precision    recall  f1-score   support
#
#           0       0.28      0.41      0.33       671
#           1       0.19      0.33      0.24       654
#           2       0.64      0.42      0.51       654
#           3       0.42      0.12      0.19       646
#           4       0.43      0.36      0.40       656
#
# avg / total       0.39      0.33      0.33      3281
#
# CONFUSION MATRIX : [[272 257  45  35  62]
#  [275 215  49  27  88]
#  [144 121 276  21  92]
#  [235 215  48  78  70]
#  [ 49 329  16  23 239]]
# SPLIT TIME: 0.362
# FIT TIME: 0.887
# SCORE TIME: 0.064
# SPLIT TIME: 0.346
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.716636782348
# MEAN PRECISION: 0.716804851648
# MEAN RECALL: 0.716721027065
# MEAN F-MEASURE: 0.707779344215
# MEAN FIT TIME: 1.68323805332
# MEAN SCORE TIME: 0.0887358427048
# END RANDOM FOREST

# %%
detection.support_vector_machine(1, apply_pca=True, number_of_components=3)
detection.support_vector_machine(2, apply_pca=True, number_of_components=8)
detection.support_vector_machine(3, apply_pca=True, number_of_components=9)
# Out:
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# ACCURACY : 0.363913441024
# REPORT :              precision    recall  f1-score   support
#
#           0       0.29      0.34      0.31       671
#           1       0.26      0.27      0.26       654
#           2       0.43      0.37      0.40       654
#           3       0.30      0.30      0.30       646
#           4       0.57      0.55      0.56       656
#
# avg / total       0.37      0.36      0.37      3281
#
# CONFUSION MATRIX : [[226 158  75 124  88]
#  [175 176 100 137  66]
#  [ 78 126 240 117  93]
#  [200 128  98 192  28]
#  [ 98  91  45  62 360]]
# SPLIT TIME: 0.338
# SCALE TIME: 0.001
# FIT TIME: 1.409
# SCORE TIME: 0.265
# SPLIT TIME: 0.339
# SCALE TIME: 0.001
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.534776810681
# MEAN PRECISION: 0.552390685921
# MEAN RECALL: 0.53491209808
# MEAN F-MEASURE: 0.516648839454
# MEAN FIT TIME: 3.23904540539
# MEAN SCORE TIME: 0.362644433975
# END SUPPORT VECTOR MACHINE.....
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.42669917708
# REPORT :              precision    recall  f1-score   support
#
#           0       0.35      0.41      0.38       671
#           1       0.36      0.48      0.41       654
#           2       0.49      0.53      0.51       654
#           3       0.37      0.27      0.31       646
#           4       0.63      0.45      0.52       656
#
# avg / total       0.44      0.43      0.43      3281
#
# CONFUSION MATRIX : [[275 171  97  77  51]
#  [110 312 112  75  45]
#  [ 89  51 346 124  44]
#  [122 201 116 175  32]
#  [184 121  42  17 292]]
# SPLIT TIME: 0.391
# SCALE TIME: 0.001
# FIT TIME: 0.822
# SCORE TIME: 0.301
# SPLIT TIME: 0.33
# SCALE TIME: 0.002
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.586625020032
# MEAN PRECISION: 0.588283592227
# MEAN RECALL: 0.586738376128
# MEAN F-MEASURE: 0.578643831861
# MEAN FIT TIME: 1.93312892914
# MEAN SCORE TIME: 0.385924601555
# END SUPPORT VECTOR MACHINE.....
# SUPPORT VECTOR MACHINE.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.316366961292
# REPORT :              precision    recall  f1-score   support
#
#           0       0.27      0.39      0.32       671
#           1       0.19      0.30      0.23       654
#           2       0.48      0.34      0.39       654
#           3       0.42      0.26      0.32       646
#           4       0.43      0.30      0.35       656
#
# avg / total       0.36      0.32      0.32      3281
#
# CONFUSION MATRIX : [[262 230  54  88  37]
#  [300 193  64  41  56]
#  [112 147 220  90  85]
#  [183 151  65 167  80]
#  [ 99 291  58  12 196]]
# SPLIT TIME: 0.354
# SCALE TIME: 0.001
# FIT TIME: 0.642
# SCORE TIME: 0.243
# SPLIT TIME: 0.35
# SCALE TIME: 0.002
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.662674935741
# MEAN PRECISION: 0.660672152129
# MEAN RECALL: 0.662758501041
# MEAN F-MEASURE: 0.653772462076
# MEAN FIT TIME: 1.51975908279
# MEAN SCORE TIME: 0.317694854736
# END SUPPORT VECTOR MACHINE.....

# %%
detection.neural_network(1, apply_pca=True, number_of_components=3)
detection.neural_network(2, apply_pca=True, number_of_components=8)
detection.neural_network(3, apply_pca=True, number_of_components=9)
# Out:
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ACCURACY : 0.380981408107
# REPORT :              precision    recall  f1-score   support
#
#           0       0.33      0.33      0.33       671
#           1       0.26      0.27      0.27       654
#           2       0.44      0.42      0.43       654
#           3       0.31      0.30      0.31       646
#           4       0.58      0.58      0.58       656
#
# avg / total       0.38      0.38      0.38      3281
#
# CONFUSION MATRIX : [[220 168  71 123  89]
#  [146 179 122 125  82]
#  [103  68 277 123  83]
#  [149 160 116 196  25]
#  [ 56 113  48  61 378]]
# SPLIT TIME: 0.338
# SCALE TIME: 0.001
# FIT TIME: 43.18
# SCORE TIME: 0.041
# SPLIT TIME: 0.344
# SCALE TIME: 0.001
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.544081449626
# MEAN PRECISION: 0.549181246092
# MEAN RECALL: 0.544214665741
# MEAN F-MEASURE: 0.526318935901
# MEAN FIT TIME: 80.016663146
# MEAN SCORE TIME: 0.0248400688171
# END NEURAL NETWORK
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# ACCURACY : 0.451386772326
# REPORT :              precision    recall  f1-score   support
#
#           0       0.40      0.48      0.44       671
#           1       0.34      0.46      0.39       654
#           2       0.55      0.50      0.52       654
#           3       0.45      0.34      0.39       646
#           4       0.63      0.48      0.54       656
#
# avg / total       0.47      0.45      0.46      3281
#
# CONFUSION MATRIX : [[319 164  77  69  42]
#  [127 301  94  86  46]
#  [ 63 100 324 105  62]
#  [ 80 225  82 221  38]
#  [206 103  17  14 316]]
# SPLIT TIME: 0.356
# SCALE TIME: 0.001
# FIT TIME: 44.375
# SCORE TIME: 0.04
# SPLIT TIME: 0.348
# SCALE TIME: 0.002
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.60963974496
# MEAN PRECISION: 0.612067292717
# MEAN RECALL: 0.609760582929
# MEAN F-MEASURE: 0.599709541462
# MEAN FIT TIME: 80.6801535368
# MEAN SCORE TIME: 0.0236329078674
# END NEURAL NETWORK
# NEURAL NETWORK.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# ACCURACY : 0.306613837245
# REPORT :              precision    recall  f1-score   support
#
#           0       0.31      0.31      0.31       671
#           1       0.17      0.31      0.22       654
#           2       0.58      0.42      0.49       654
#           3       0.29      0.21      0.24       646
#           4       0.42      0.27      0.33       656
#
# avg / total       0.35      0.31      0.32      3281
#
# CONFUSION MATRIX : [[211 306  55  74  25]
#  [239 204  77  69  65]
#  [ 65  95 277 151  66]
#  [104 270  50 134  88]
#  [ 64 356  18  38 180]]
# SPLIT TIME: 0.355
# SCALE TIME: 0.001
# FIT TIME: 33.291
# SCORE TIME: 0.03
# SPLIT TIME: 0.348
# SCALE TIME: 0.002
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.691465459483
# MEAN PRECISION: 0.688234514119
# MEAN RECALL: 0.691564885496
# MEAN F-MEASURE: 0.678984983558
# MEAN FIT TIME: 57.0741565943
# MEAN SCORE TIME: 0.016638302803
# END NEURAL NETWORK
# /home/elton_soares/anaconda3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
detection.auto_machine_learning(1, search_time=300, apply_pca=True, number_of_components=3)
detection.auto_machine_learning(2, search_time=300, apply_pca=True, number_of_components=8)
detection.auto_machine_learning(3, search_time=300, apply_pca=True, number_of_components=9)
# Out:
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'gyroscope']
# NUMBER OF FEATURES:  18
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.510710)
# StatusType.SUCCESS 0.430286241921 0.9155220985412598 {'num_run': 2, 'duration': 0.8596572875976562}
# StatusType.SUCCESS 0.457063711911 0.599766731262207 {'num_run': 3, 'duration': 0.568511962890625}
# StatusType.SUCCESS 0.454293628809 3.2111310958862305 {'num_run': 4, 'duration': 3.0911524295806885}
# StatusType.SUCCESS 0.427516158818 38.515496492385864 {'num_run': 5, 'duration': 38.38970923423767}
# StatusType.SUCCESS 0.432132963989 5.751528024673462 {'num_run': 6, 'duration': 5.717558860778809}
# StatusType.SUCCESS 0.489381348107 0.5619542598724365 {'num_run': 7, 'duration': 0.5258638858795166}
# StatusType.SUCCESS 0.454293628809 0.7848351001739502 {'num_run': 8, 'duration': 0.7470982074737549}
# StatusType.SUCCESS 0.493998153278 12.247459888458252 {'num_run': 9, 'duration': 12.215571641921997}
# StatusType.SUCCESS 0.46999076639 2.3930461406707764 {'num_run': 10, 'duration': 2.3489274978637695}
# StatusType.SUCCESS 0.444136657433 2.9711954593658447 {'num_run': 11, 'duration': 2.855964422225952}
# StatusType.SUCCESS 0.578024007387 0.7584178447723389 {'num_run': 12, 'duration': 0.712721586227417}
# StatusType.SUCCESS 0.449676823638 0.848308801651001 {'num_run': 13, 'duration': 0.8177187442779541}
# StatusType.SUCCESS 0.47460757156 1.3550424575805664 {'num_run': 14, 'duration': 1.3223810195922852}
# StatusType.SUCCESS 0.444136657433 10.190786361694336 {'num_run': 15, 'duration': 10.023613929748535}
# StatusType.SUCCESS 0.501385041551 4.3515050411224365 {'num_run': 16, 'duration': 4.305813789367676}
# StatusType.SUCCESS 0.452446906741 0.822700023651123 {'num_run': 17, 'duration': 0.7919011116027832}
# StatusType.TIMEOUT 1.0 201.10822987556458 {'error': 'Timeout'}
# ACCURACY : 0.388601036269
# REPORT :              precision    recall  f1-score   support
#
#           0       0.32      0.31      0.31       671
#           1       0.26      0.29      0.27       654
#           2       0.46      0.57      0.51       654
#           3       0.40      0.30      0.35       646
#           4       0.53      0.47      0.50       656
#
# avg / total       0.39      0.39      0.39      3281
#
# CONFUSION MATRIX : [[209 176  95  86 105]
#  [132 190 160  91  81]
#  [ 84  80 372  69  49]
#  [113 163 131 197  42]
#  [119 131  49  50 307]]
# SPLIT TIME: 0.343
# FIT TIME: 298.59
# SCORE TIME: 1.496
# FINAL ENSEMBLE: [(0.860000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.060000, SimpleClassificationPipeline({'preprocessor:pca:whiten': 'True', 'classifier:extra_trees:criterion': 'entropy', 'classifier:extra_trees:max_features': 1.5031924010427555, 'classifier:extra_trees:bootstrap': 'True', 'classifier:extra_trees:max_depth': 'None', 'balancing:strategy': 'none', 'classifier:__choice__': 'extra_trees', 'classifier:extra_trees:min_weight_fraction_leaf': 0.0, 'classifier:extra_trees:min_samples_split': 8, 'rescaling:__choice__': 'none', 'preprocessor:pca:keep_variance': 0.5440040750402232, 'preprocessor:__choice__': 'pca', 'classifier:extra_trees:min_samples_leaf': 4, 'one_hot_encoding:use_minimum_fraction': 'False', 'imputation:strategy': 'mean', 'classifier:extra_trees:n_estimators': 100},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.040000, SimpleClassificationPipeline({'classifier:random_forest:max_features': 1.0, 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'classifier:random_forest:criterion': 'gini', 'one_hot_encoding:minimum_fraction': 0.01, 'balancing:strategy': 'none', 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:bootstrap': 'True', 'classifier:__choice__': 'random_forest', 'rescaling:__choice__': 'standardize', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean', 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:libsvm_svc:shrinking': 'False', 'classifier:libsvm_svc:gamma': 1.421889512788389, 'classifier:libsvm_svc:tol': 0.07228314195704957, 'classifier:libsvm_svc:kernel': 'rbf', 'classifier:libsvm_svc:max_iter': -1, 'balancing:strategy': 'none', 'classifier:libsvm_svc:C': 133.619004912714, 'classifier:__choice__': 'libsvm_svc', 'rescaling:__choice__': 'minmax', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'False', 'imputation:strategy': 'median'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.32
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.606298462756
# MEAN PRECISION: 0.609659177587
# MEAN RECALL: 0.606407587324
# MEAN F-MEASURE: 0.604567898971
# MEAN FIT TIME: 268.6612
# MEAN SCORE TIME: 0.667
# END AUTO MACHINE LEARNING
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector']
# NUMBER OF FEATURES:  48
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.508911)
# StatusType.SUCCESS 0.251154201293 1.197216510772705 {'num_run': 2, 'duration': 1.133394718170166}
# StatusType.SUCCESS 0.277931671283 6.205536603927612 {'num_run': 3, 'duration': 6.136524438858032}
# StatusType.SUCCESS 0.354570637119 0.8304784297943115 {'num_run': 4, 'duration': 0.7949879169464111}
# StatusType.SUCCESS 0.32594644506 0.6178774833679199 {'num_run': 5, 'duration': 0.5827236175537109}
# StatusType.SUCCESS 0.382271468144 0.8081386089324951 {'num_run': 6, 'duration': 0.773993968963623}
# StatusType.SUCCESS 0.236380424746 41.266812562942505 {'num_run': 7, 'duration': 41.147324085235596}
# StatusType.SUCCESS 0.376731301939 3.884227752685547 {'num_run': 8, 'duration': 3.8499457836151123}
# StatusType.SUCCESS 0.350877192982 1.1758480072021484 {'num_run': 9, 'duration': 1.1427366733551025}
# StatusType.SUCCESS 0.319482917821 4.419719934463501 {'num_run': 10, 'duration': 4.371984481811523}
# StatusType.SUCCESS 0.265004616805 5.549495697021484 {'num_run': 11, 'duration': 5.483729600906372}
# StatusType.SUCCESS 0.396121883657 4.38667893409729 {'num_run': 12, 'duration': 4.328362941741943}
# StatusType.SUCCESS 0.573407202216 0.7687563896179199 {'num_run': 13, 'duration': 0.7196269035339355}
# StatusType.SUCCESS 0.333333333333 1.2055089473724365 {'num_run': 14, 'duration': 1.1664035320281982}
# StatusType.TIMEOUT 1.0 215.1089153289795 {'error': 'Timeout'}
# ACCURACY : 0.519658640658
# REPORT :              precision    recall  f1-score   support
#
#           0       0.48      0.60      0.53       671
#           1       0.43      0.52      0.47       654
#           2       0.63      0.50      0.56       654
#           3       0.53      0.38      0.44       646
#           4       0.59      0.59      0.59       656
#
# avg / total       0.53      0.52      0.52      3281
#
# CONFUSION MATRIX : [[400  95  53  50  73]
#  [112 342  58  75  67]
#  [ 96  62 330  78  88]
#  [111 185  61 247  42]
#  [116 113  21  20 386]]
# SPLIT TIME: 0.344
# FIT TIME: 297.306
# SCORE TIME: 1.158
# FINAL ENSEMBLE: [(0.920000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.020000, SimpleClassificationPipeline({'classifier:random_forest:max_features': 1.0, 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'classifier:random_forest:criterion': 'gini', 'one_hot_encoding:minimum_fraction': 0.01, 'balancing:strategy': 'none', 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:bootstrap': 'True', 'classifier:__choice__': 'random_forest', 'rescaling:__choice__': 'standardize', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean', 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:__choice__': 'k_nearest_neighbors', 'classifier:k_nearest_neighbors:n_neighbors': 2, 'rescaling:__choice__': 'none', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:minimum_fraction': 0.3530578080502024, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean', 'classifier:k_nearest_neighbors:p': 1, 'classifier:k_nearest_neighbors:weights': 'distance', 'balancing:strategy': 'weighting'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:libsvm_svc:shrinking': 'True', 'preprocessor:polynomial:include_bias': 'True', 'classifier:libsvm_svc:gamma': 0.1597932521120146, 'classifier:libsvm_svc:tol': 0.00013911955271793795, 'preprocessor:polynomial:interaction_only': 'False', 'preprocessor:polynomial:degree': 2, 'classifier:libsvm_svc:kernel': 'rbf', 'classifier:libsvm_svc:max_iter': -1, 'balancing:strategy': 'weighting', 'classifier:libsvm_svc:C': 17304.617799701293, 'classifier:__choice__': 'libsvm_svc', 'rescaling:__choice__': 'normalize', 'preprocessor:__choice__': 'polynomial', 'one_hot_encoding:use_minimum_fraction': 'False', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.315
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.815557696389
# MEAN PRECISION: 0.81712679319
# MEAN RECALL: 0.815602590793
# MEAN F-MEASURE: 0.815753546113
# MEAN FIT TIME: 146.0957
# MEAN SCORE TIME: 0.4934
# END AUTO MACHINE LEARNING
# AUTO MACHINE LEARNING.....
# CLASSIFICATION BASED ON THESE SENSORS:  ['accelerometer', 'sound', 'orientation', 'linear_acceleration', 'gyroscope_uncalibrated', 'gyroscope', 'game_rotation_vector', 'rotation_vector', 'speed']
# NUMBER OF FEATURES:  54
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.395364)
# StatusType.SUCCESS 0.197599261311 1.2330760955810547 {'num_run': 2, 'duration': 1.1799380779266357}
# StatusType.SUCCESS 0.20406278855 6.938917398452759 {'num_run': 3, 'duration': 6.868324279785156}
# StatusType.SUCCESS 0.250230840259 0.6548020839691162 {'num_run': 4, 'duration': 0.6151089668273926}
# StatusType.SUCCESS 0.183748845799 42.605132818222046 {'num_run': 5, 'duration': 42.47387099266052}
# StatusType.SUCCESS 0.283471837488 0.8122522830963135 {'num_run': 6, 'duration': 0.7783389091491699}
# StatusType.SUCCESS 0.31486611265 0.9421610832214355 {'num_run': 7, 'duration': 0.9042394161224365}
# StatusType.SUCCESS 0.302862419206 3.5542500019073486 {'num_run': 8, 'duration': 3.5185012817382812}
# StatusType.SUCCESS 0.286241920591 1.0338733196258545 {'num_run': 9, 'duration': 0.9966578483581543}
# StatusType.SUCCESS 0.272391505078 4.561848878860474 {'num_run': 10, 'duration': 4.5122315883636475}
# StatusType.SUCCESS 0.187442289935 6.404895544052124 {'num_run': 11, 'duration': 6.340959310531616}
# StatusType.SUCCESS 0.578024007387 0.7994856834411621 {'num_run': 12, 'duration': 0.7515408992767334}
# StatusType.SUCCESS 0.308402585411 4.105393171310425 {'num_run': 13, 'duration': 4.050137281417847}
# StatusType.SUCCESS 0.271468144044 1.2019870281219482 {'num_run': 14, 'duration': 1.1677427291870117}
# StatusType.TIMEOUT 1.0 212.1109495162964 {'error': 'Timeout'}
# ACCURACY : 0.400487656202
# REPORT :              precision    recall  f1-score   support
#
#           0       0.43      0.41      0.42       671
#           1       0.25      0.43      0.31       654
#           2       0.64      0.43      0.52       654
#           3       0.53      0.22      0.31       646
#           4       0.42      0.51      0.46       656
#
# avg / total       0.45      0.40      0.40      3281
#
# CONFUSION MATRIX : [[275 230  44  30  92]
#  [143 279  54  37 141]
#  [ 86 123 283  44 118]
#  [101 242  43 140 120]
#  [ 33 260  15  11 337]]
# SPLIT TIME: 0.366
# FIT TIME: 296.304
# SCORE TIME: 1.464
# FINAL ENSEMBLE: [(0.940000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.020000, SimpleClassificationPipeline({'classifier:gradient_boosting:subsample': 0.6289005711340923, 'classifier:gradient_boosting:max_depth': 10, 'classifier:gradient_boosting:loss': 'deviance', 'classifier:gradient_boosting:min_weight_fraction_leaf': 0.0, 'one_hot_encoding:minimum_fraction': 0.0002148748655476835, 'balancing:strategy': 'weighting', 'classifier:gradient_boosting:max_features': 4.211238636565405, 'classifier:gradient_boosting:learning_rate': 0.03627152792976942, 'classifier:gradient_boosting:n_estimators': 340, 'classifier:__choice__': 'gradient_boosting', 'classifier:gradient_boosting:max_leaf_nodes': 'None', 'rescaling:__choice__': 'standardize', 'classifier:gradient_boosting:min_samples_leaf': 15, 'preprocessor:__choice__': 'no_preprocessing', 'classifier:gradient_boosting:min_samples_split': 16, 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'mean'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:gamma': 0.008590925713214136, 'classifier:libsvm_svc:tol': 0.08183987642157002, 'classifier:libsvm_svc:kernel': 'rbf', 'classifier:libsvm_svc:max_iter': -1, 'balancing:strategy': 'none', 'classifier:libsvm_svc:C': 16725.85790752666, 'classifier:__choice__': 'libsvm_svc', 'rescaling:__choice__': 'none', 'preprocessor:__choice__': 'no_preprocessing', 'one_hot_encoding:use_minimum_fraction': 'False', 'imputation:strategy': 'median'},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# (0.020000, SimpleClassificationPipeline({'preprocessor:polynomial:include_bias': 'True', 'classifier:random_forest:max_features': 1.675620724347966, 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'classifier:random_forest:criterion': 'entropy', 'one_hot_encoding:minimum_fraction': 0.14577676557539165, 'balancing:strategy': 'weighting', 'preprocessor:polynomial:degree': 3, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:bootstrap': 'True', 'preprocessor:polynomial:interaction_only': 'True', 'classifier:__choice__': 'random_forest', 'rescaling:__choice__': 'normalize', 'preprocessor:__choice__': 'polynomial', 'one_hot_encoding:use_minimum_fraction': 'True', 'imputation:strategy': 'most_frequent', 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 15},
# dataset_properties={
#   'sparse': False,
#   'task': 2,
#   'signed': False,
#   'target_type': 'classification',
#   'multiclass': True,
#   'multilabel': False})),
# ]
# SPLIT TIME: 0.332
# 10 -Fold Cross Validation Results
# MEAN ACCURACY: 0.866952640334
# MEAN PRECISION: 0.868641706343
# MEAN RECALL: 0.866995142262
# MEAN F-MEASURE: 0.866701828177
# MEAN FIT TIME: 157.0423
# MEAN SCORE TIME: 0.6201
# END AUTO MACHINE LEARNING
